# %% [markdown]
# # Task 4.6 - Combining & Exporting Data - Answers

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved

# %%
#Create folder path
path=r'C:\Users\Utilizador\OneDrive\Documents\CareerFoundry - Data Analyst\Data Immersion\A4\19-01-2024 Instacart Basket Analysis'

# %%
#Import merged orders.csv and orders_products_prior.csv pickle file
df_ords_prods=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
#check output
df_ords_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    is_first_order  product_id  add_to_cart_order  reordered _merge
# 0               1         196                  1          0   both
# 1               1       14084                  2          0   both
# ...

# %% [markdown]
# #### 4. Check the shape of the imported dataframe.

# %%
#check shape of combined orders and products
df_ords_prods.shape
# Out:
# (32434489, 13)

# %% [markdown]
# The shape matches the shape of the exported df of (32434489, 11)

# %%
#delete _merge column as new df
df_ords_prods_2=df_ords_prods.drop(columns=['_merge'])

# %%
#check output
df_ords_prods_2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    is_first_order  product_id  add_to_cart_order  reordered
# 0               1         196                  1          0
# 1               1       14084                  2          0
# ...

# %%
df_ords_prods_2.shape
# Out:
# (32434489, 12)

# %% [markdown]
# #### 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
#Import Checked products.csv
df_prods=pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'),index_col=False)

# %%
#Check output
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Delete unnecessary index column 'Unnamed: 0'
df_prods=df_prods.drop(columns=['Unnamed: 0'])

# %%
#Check output
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
#test left join merge
pd.merge(df_ords_prods_2,df_prods,on=['product_id'],indicator=True)
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    1           1   2398795        1             2
# 2                    2           2    473747        1             3
# 3                    3           3   2254736        1             4
# 4                    4           4    431534        1             5
# ...                ...         ...       ...      ...           ...
# 32404854       3360493     3360493   1320836   202557            17
# 32404855       3360494     3360494     31526   202557            18
# 32404856       3376038     3376038    758936   203436             1
# 32404857       3376039     3376039   2745165   203436             2
# 32404858       3408036     3408036   3093936   205420             1
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
#Inner merge the two dataframes
df_merged_inner=pd.merge(df_ords_prods_2,df_prods,on=['product_id'],indicator=True)

# %%
#check inner merge output
df_merged_inner.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
#
#    is_first_order  product_id  add_to_cart_order  reordered product_name  \
# 0               1         196                  1          0         Soda
# ...

# %%
#check merge shape
df_merged_inner.shape
# Out:
# (32404859, 17)

# %% [markdown]
# #### 6. Confirm the results of the merge using the merge flag.

# %%
#check inner merge flags
df_merged_inner[('_merge')].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 7. Export the newly created dataframe as ords_prods_merge in a suitable format (taking into consideration the size).

# %%
#Export merged dataframes to pickle format
df_merged_inner.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge.pkl'))

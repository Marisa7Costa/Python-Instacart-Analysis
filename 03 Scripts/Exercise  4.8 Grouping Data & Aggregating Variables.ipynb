# %% [markdown]
# ## 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ### Content List
# #### 01. Import Libraries
# #### 02. Import Updated Dataset
# #### 03. Data checks
# #### 04. Grouping Data - Aggregating Data with agg(); Aggregating Data with transform (); Deriving columns with loc()

# %% [markdown]
# ### 01. Import Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02. Import Updated Dataset

# %%
#Create folder path
path = r'C:\Users\Utilizador\OneDrive\Documents\CareerFoundry - Data Analyst\Data Immersion\A4\19-01-2024 Instacart Basket Analysis'

# %%
#Import dataset
ords_prods_merge = pd.read_pickle (os.path.join(path, '02 Data','Prepared Data','ords_prods_newvar.pkl'))

# %%
#Check imported df
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
#
#    is_first_order  product_id  ...  reordered  product_name aisle_id  \
# 0               1         196  ...          0          Soda       77
# 1               0         196  ...          1          Soda       77
# 2               0         196  ...          1          Soda       77
# 3               0         196  ...          1          Soda       77
# 4               0         196  ...          1          Soda       77
#
#    department_id  prices  _merge    price_range_loc     busiest_day  \
# 0              7     9.0    both  Mid-range product  Regularly busy
# 1              7     9.0    both  Mid-range product  Regularly busy
# 2              7     9.0    both  Mid-range product  Regularly busy
# 3              7     9.0    both  Mid-range product      Least busy
# 4              7     9.0    both  Mid-range product      Least busy
#
#    busiest_days busiest_period_of_day
# 0  Regular days           Most orders
# 1  Slowest days           Most orders
# 2  Slowest days        Average orders
# 3  Slowest days           Most orders
# 4  Slowest days        Average orders
#
# [5 rows x 21 columns]

# %%
#Delete columns 'Unnamed: 0.1' & 'Unnamed: 0'
ords_prods_merge =ords_prods_merge.drop(columns =['Unnamed: 0.1', 'Unnamed: 0'])

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  is_first_order  product_id  add_to_cart_order  \
# 0                     NaN               1         196                  1
# 1                    15.0               0         196                  1
# 2                    21.0               0         196                  1
# 3                    29.0               0         196                  1
# 4                    28.0               0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day  busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regular days           Most orders
# 1  Mid-range product  Regularly busy  Slowest days           Most orders
# 2  Mid-range product  Regularly busy  Slowest days        Average orders
# 3  Mid-range product      Least busy  Slowest days           Most orders
# 4  Mid-range product      Least busy  Slowest days        Average orders

# %%
#check shape
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
#Subset first one million entries
df = ords_prods_merge[:1000000]

# %% [markdown]
# ### 03. Data checks

# %%
#Check shape of data
df.shape
# Out:
# (1000000, 19)

# %%
#check dataframe 
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  is_first_order  product_id  add_to_cart_order  \
# 0                     NaN               1         196                  1
# 1                    15.0               0         196                  1
# 2                    21.0               0         196                  1
# 3                    29.0               0         196                  1
# 4                    28.0               0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day  busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regular days           Most orders
# 1  Mid-range product  Regularly busy  Slowest days           Most orders
# 2  Mid-range product  Regularly busy  Slowest days        Average orders
# 3  Mid-range product      Least busy  Slowest days           Most orders
# 4  Mid-range product      Least busy  Slowest days        Average orders

# %% [markdown]
# ### 04. Grouping Data

# %%
#Group by product_name
df.groupby('product_name')

# %% [markdown]
# #### Aggregating Data with agg()

# %%
#Performing a single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# #### Aggregating Data with transform ()

# %%
#Identify Loyal cutomers - group orders by user to generate max orders per user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Utilizador\AppData\Local\Temp\ipykernel_9468\1598536146.py:2: FutureWarning: The provided callable <function amax at 0x000002327C9D1E40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Check output
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  is_first_order  product_id  add_to_cart_order  \
# 0                      NaN               1         196                  1
# 1                     15.0               0         196                  1
# 2                     21.0               0         196                  1
# 3                     29.0               0         196                  1
# 4                     28.0               0         196                  1
# ..                     ...             ...         ...                ...
# 95                     NaN               1         196                  1
# 96                     3.0               0         196                  9
# 97                    22.0               0         196                  3
# 98                    30.0               0         196                  2
# 99                    16.0               0         196                  2
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# ..        ...          ...       ...            ...     ...    ...
# 95          0         Soda        77              7     9.0   both
# 96          0         Soda        77              7     9.0   both
# 97          0         Soda        77              7     9.0   both
# 98          0         Soda        77              7     9.0   both
# 99          1         Soda        77              7     9.0   both
#
#       price_range_loc     busiest_day  busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regular days           Most orders
# 1   Mid-range product  Regularly busy  Slowest days           Most orders
# 2   Mid-range product  Regularly busy  Slowest days        Average orders
# 3   Mid-range product      Least busy  Slowest days           Most orders
# 4   Mid-range product      Least busy  Slowest days        Average orders
# ..                ...             ...           ...                   ...
# 95  Mid-range product  Regularly busy  Regular days        Average orders
# 96  Mid-range product  Regularly busy  Regular days           Most orders
# 97  Mid-range product      Least busy  Slowest days        Average orders
# 98  Mid-range product  Regularly busy  Busiest days           Most orders
# 99  Mid-range product  Regularly busy  Slowest days           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# ..        ...
# 95          3
# 96          3
# 97          8
# 98         22
# 99         22
#
# [100 rows x 20 columns]

# %%
#Stop pandas from limiting number of entries displayed
pd.options.display.max_rows = None

# %%
#Check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  is_first_order  product_id  add_to_cart_order  \
# 0                     NaN               1         196                  1
# 1                    15.0               0         196                  1
# 2                    21.0               0         196                  1
# 3                    29.0               0         196                  1
# 4                    28.0               0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day  busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regular days           Most orders
# 1  Mid-range product  Regularly busy  Slowest days           Most orders
# 2  Mid-range product  Regularly busy  Slowest days        Average orders
# 3  Mid-range product      Least busy  Slowest days           Most orders
# 4  Mid-range product      Least busy  Slowest days        Average orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10

# %% [markdown]
# #### Deriving columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64
